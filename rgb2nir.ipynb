# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 1381, done.
# remote: Total 1381 (delta 0), reused 0 (delta 0), pack-reused 1381
# Receiving objects: 100% (1381/1381), 7.70 MiB | 14.57 MiB/s, done.
# Resolving deltas: 100% (905/905), done.

# %%
# !pip install -r pytorch-CycleGAN-and-pix2pix/requirements.txt
# Out:
# ...
#     100% |████████████████████████████████| 519.5MB 33kB/s
# tcmalloc: large alloc 1073750016 bytes == 0x596e0000 @  0x7f098e9371c4 0x46d6a4 0x5fcbcc 0x4c494d 0x54f3c4 0x553aaf 0x54e4c8 0x54f4f6 0x553aaf 0x54efc1 0x54f24d 0x553aaf 0x54efc1 0x54f24d 0x553aaf 0x54efc1 0x54f24d 0x551ee0 0x54e4c8 0x54f4f6 0x553aaf 0x54efc1 0x54f24d 0x551ee0 0x54efc1 0x54f24d 0x551ee0 0x54e4c8 0x54f4f6 0x553aaf 0x54e4c8
# ...
#     100% |████████████████████████████████| 61kB 8.0MB/s
# ...
#     100% |████████████████████████████████| 256kB 9.4MB/s
# ...
#     100% |████████████████████████████████| 2.0MB 5.0MB/s
# ...
#     100% |████████████████████████████████| 204kB 27.4MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/fb/ef/d8/ad95fbafb505c507b476c4e907af570d2dd41ae725cdc9b391
# done
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built visdom torchfile
# ...
#   Found existing installation: Pillow 4.0.0
#     Uninstalling Pillow-4.0.0:
# ...

# %%
from google.colab import drive
drive.mount('./drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at ./drive

# %%
# !cp ./drive/My\ Drive/rgb2nir.zip .

# %%
# !unzip rgb2nir.zip

# %%
# !cd ./pytorch-CycleGAN-and-pix2pix && python train.py --dataroot ../rgb2nir --name rgb2nir --model cycle_gan --display_server http://18.222.192.50
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                  dataroot: ../drive/My Drive/sketch2fomenko	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://18.222.192.50          	[default: http://localhost]
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  fineSize: 256
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
#                  lambda_B: 10.0
# ...

# %%
python style.py --style path/to/style/img.jpg \
  --checkpoint-dir checkpoint/path \
  --test path/to/test/img.jpg \
  --test-dir path/to/test/dir \
  --content-weight 1.5e1 \
  --checkpoint-iterations 1000 \
  --batch-size 20

# %%
# !cp -r ./drive/My\ Drive/rgb2nir ./rgb2nir
